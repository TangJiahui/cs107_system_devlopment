# %% [markdown]
# ## Group Members
# Jiahui Tang, Benjamin Liu, Aleksander Aleksiev, and Xiaohan Yang

# %% [markdown]
# **Exercise 1 Part A**
#
# $$J = \begin{bmatrix}2x & 2y \\ e^{x+y} & e^{x+y}\end{bmatrix}$$
#
# At point (1,1), $$J = \begin{bmatrix}2 & 2 \\ 7.389 & 7.389\end{bmatrix}$$
#
# **Exercise 1 Part B**
#
# i)
#
# $$Jp = \begin{bmatrix}2x & 2y \\ e^{x+y} & e^{x+y}\end{bmatrix} \begin{bmatrix}1 \\ -2\end{bmatrix} = \begin{bmatrix}2x - 4y \\ -e^{x+y}\end{bmatrix}$$
#
# ii)
#
# $$Jp = \begin{bmatrix}2x & 2y \\ e^{x+y} & e^{x+y}\end{bmatrix} \begin{bmatrix}1 \\ 1\end{bmatrix} = \begin{bmatrix}2x + 2y \\ 2e^{x+y}\end{bmatrix}$$

# %% [markdown]
# **Exercise 1 Part C**
#
# | trace | elem op.   | value       | elem deriv.        | $\nabla_{x}$ | $\nabla_{y}$ |
# | :---: | :---:      | :---------: |   :---:            |:---:         |:---:         |
# | $x_1$ | $x_1$      | $1$         | $\dot{x_1}$        | $1$          | $1$          |
# | $x_2$ | $x_2$      | $1$         | $\dot{x_2}$        | $-2$         | $1$          |
# | $v_1$ | $x_1^2$    | $1$         | $2x_1\dot{x_1}$    | $2$          | $2$          |
# | $v_2$ | $x_2^2$    | $1$         | $2x_2\dot{x_2}$    | $-4$         | $2$          |
# | $v_3$ | $x_1 + x_2$| $2$         | $\dot{x_1} + \dot{x_2}$ | $-1$     | $2$          |
# | $v_4$ | $v_1 + v_2$| $2$         | $\dot{v_1} + \dot{v_2}$ | $-2$    | $4$          |
# | $v_5$ | $e^{v_3}$  | $7.389$     | $e^{v_3}\dot{v_3}$       | $-7.389$   | $14.778$  |
# | $f$ | $[v_4,v_5]$  | $[2, 7.389]$   | $[\dot{v_4},\dot{v_5}]$       | $[-2,-7.389]$   | $[4,14.778]$  |
#
#
# *Note*: The numerical value at final row in trace table on $\nabla_{x}$ and $\nabla_{y}$ are the same
# as plugging in (1,1) into $Jp$ in part B.
